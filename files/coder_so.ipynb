# %%
# %load_ext autoreload
# %autoreload 2

import coder_so
from coder_so import formal

# %%
A=coder_so.DW(N=2)
A.print_nice()
# Out:
# <style>.container{width:auto!important;}
#  .output_area img{width:auto!important;}
#  .rendered_html img{width:auto!important;}</style><nobr /><img src="data:image/png;base64,..." style="max-width:none;"/><nobr />

# %%
B=formal.I.tensor(formal.I)+formal.P-formal.Q

# %%
(A*B).sort().print_nice()
# Out:
# <style>.container{width:auto!important;}
#  .output_area img{width:auto!important;}
#  .rendered_html img{width:auto!important;}</style><nobr /><img src="data:image/png;base64,..." style="max-width:none;"/><nobr />

# %%
import time 
# %timeit AA=(A*formal.Q).sort()
# Out:
# 4.23 ms ± 155 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
A=coder_so.formal(coder_so.g)
A.print_nice()
# Out:
# <style>.container{width:auto!important;}
#  .output_area img{width:auto!important;}
#  .rendered_html img{width:auto!important;}</style><nobr /><img src="data:image/png;base64,..." style="max-width:none;"/><nobr />

# %%
coder_so.tensor(A,r=3).array
# Out:
# [[1/x(3), 0, 0, 0, 0, 0], [0, 1/x(2), 0, 0, 0, 0], [0, 0, 1/x(1), 0, 0, 0], [0, 0, 0, x(1), 0, 0], [0, 0, 0, 0, x(2), 0], [0, 0, 0, 0, 0, x(3)]]

# %%
coder_so.DW(term=["trD"],N=1).print_nice()
# Out:
# <style>.container{width:auto!important;}
#  .output_area img{width:auto!important;}
#  .rendered_html img{width:auto!important;}</style><nobr /><img src="data:image/png;base64,..." style="max-width:none;"/><nobr />

# %%
coder_so.tensor(coder_so.DW(term=["trD"],N=1),r=2).array
# Out:
# [[trace(gzrat(z)), 0, 0, 0], [0, trace(gzrat(z)), 0, 0], [0, 0, trace(gzrat(z)), 0], [0, 0, 0, trace(gzrat(z))]]

# %%
coder_so.tensor(coder_so.DW(term=["trD"],N=1),r=2,random="float").array.todense()

# %%
print(str(coder_so.tensor(A,r=3,random="float").array.todense()))
# Out:
# [[1.29868193 0.         0.         0.         0.         0.        ]
#  [0.         1.11072913 0.         0.         0.         0.        ]
#  [0.         0.         1.86171247 0.         0.         0.        ]
#  [0.         0.         0.         0.53713987 0.         0.        ]
#  [0.         0.         0.         0.         0.90030951 0.        ]
#  [0.         0.         0.         0.         0.         0.77001149]]

# %%
_.array.todense()
# Out:
# array([[7.29258265, 0.        , 0.        , 0.        , 0.        ,
#         0.        ],
#        [0.        , 1.59300286, 0.        , 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 2.18544584, 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , 0.45757254, 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , 0.        , 0.62774526,
#         0.        ],
#        [0.        , 0.        , 0.        , 0.        , 0.        ,
#         0.13712563]], dtype=float128)

# %%
(coder_so.tensor(A,r=3)+coder_so.tensor(A,r=3,random="float")).array
# Out:
# [[7.29258264969798464 + 1/x(3), 0, 0, 0, 0, 0], [0, 1.59300286215005671 + 1/x(2), 0, 0, 0, 0], [0, 0, 2.18544583897383449 + 1/x(1), 0, 0, 0], [0, 0, 0, x(1) + 0.457572538365693449, 0, 0], [0, 0, 0, 0, x(2) + 0.62774526258560015, 0], [0, 0, 0, 0, 0, x(3) + 0.137125631348369303]]

# %%
type(_)
# Out:
# sympy.tensor.array.sparse_ndim_array.ImmutableSparseNDimArray

# %%
A=coder_so.DW(N=2)
A.print_nice()

# %%
for z in A.coefs(coder_so.z,2):
    if z==0: print(0)
    else: z.print_nice()
# Out:
# 0
# <style>.container{width:auto!important;}
#  .output_area img{width:auto!important;}
#  .rendered_html img{width:auto!important;}</style><nobr /><img src="data:image/png;base64,..." style="max-width:none;"/><nobr />
# <style>.container{width:auto!important;}
#  .output_area img{width:auto!important;}
#  .rendered_html img{width:auto!important;}</style><nobr /><img src="data:image/png;base64,..." style="max-width:none;"/><nobr />

# %%
AA=coder_so.SymT(N=2,s=2)

# %%
len(AA._terms_)
# Out:
# 1062

# %%
sum(AA._terms_[:10]).print_nice()
# Out:
# <style>.container{width:auto!important;}
#  .output_area img{width:auto!important;}
#  .rendered_html img{width:auto!important;}</style><nobr /><img src="data:image/png;base64,..." style="max-width:none;"/><nobr />

# %%
sympy.sympify(5)-True
# Out:
# 4

# %%
2-(3>1)
# Out:
# 1

# %%
coder_so.formal.tmp0
# Out:
# [u(1), u(1)]

# %%
A=coder_so.formal.tmp[1][2]

# %%
A._terms_
# Out:
# [formal(factors=[(1, 2, g**2),(2, 1, 1)], nb_inds=2),
#  formal(factors=[(1, 2, g),(2, 1, g)], nb_inds=2),
#  formal(factors=[(1, 2, 0),(2, 1, g**2)], nb_inds=2)]

# %%
"formal(terms=["+",".join(str(i) for i in A.terms())+"])"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_69808/2091972093.py in <module>
# ----> 1 "formal(terms=["+",".join(str(i) for i in A.terms())+"])"
#
# TypeError: 'list' object is not callable

# %%
A.terms
# Out:
# [formal(factors=[(1, 2, g**2),(2, 1, 1)], nb_inds=2),
#  formal(factors=[(1, 2, g),(2, 1, g)], nb_inds=2)]

# %%
str(coder_so.formal.tmp[1][2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_69808/1622962621.py in <module>
# ----> 1 str(coder_so.formal.tmp[1][2])
#
# ~/git/aldarak_leurent/leurent/coder_so.py in __repr__(self)
#     148     def __rsub__(B,A): return A+(-1)*B
#     149     def __repr__(self):
# --> 150         if self.issum: return "formal(terms=["+",".join(str(i) for i in self.terms())+"])"
#     151         else: return "formal(factors=["+",".join(str(i) for i in self.factors)+"], nb_inds="+str(self.nb_inds)+")"
#     152     def sort(self): # standardise the order (and writing) of factors
#
# TypeError: 'list' object is not callable

# %%
coder_so.formal.tmp[0]
# Out:
# (0, 0, -1)

# %%
type(_[-1])
# Out:
# int

# %%
A=-1

# %%
[ i for i in dir(A) if "real" in i.lower() ]
# Out:
# ['real']

# %%
coder_so.formal.tmp.print_nice()
# Out:
# <style>.container{width:auto!important;}
#  .output_area img{width:auto!important;}
#  .rendered_html img{width:auto!important;}</style><nobr /><img src="data:image/png;base64,..." style="max-width:none;"/><nobr />

# %%
coder_so.formal.tmp
# Out:
# [[-1, 0, 0], [0, 1/g, g**(-2)]]

# %%
coder_so.formal.tmp0
# Out:
# (-1, gzrat(z, prim))

# %%
coder_so.formal.tmp0[-1]
# Out:
# gzrat(z, prim)

# %%
type(coder_so.formal.tmp0[0])
# Out:
# sympy.core.numbers.NegativeOne

# %%
A=coder_so.formal.tmp0[0]

# %%
import sympy
A=sympy.sympify(-1)

# %%
A=sympy.sympify(-1)

# %%
A.rea

# %%
A.is_number
# Out:
# True

# %%
A
# Out:
# -1

# %%
A.floor

# %%
B=coder_so.gzrat(coder_so.z)

# %%
B.re

# %%
coder_so.gzrat(coder_so.z).is_number
# Out:
# False

# %%
hasattr

# %%
[ i for i in dir(A) if "num" in i.lower()]
# Out:
# ['as_numer_denom',
#  'is_AlgebraicNumber',
#  'is_Number',
#  'is_NumberSymbol',
#  'is_number',
#  'numerator']

# %%
pip install sparse
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached sparse-0.13.0-py2.py3-none-any.whl (77 kB)
# ...
#   Using cached numba-0.56.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.5 MB)
# ...
#   Using cached llvmlite-0.39.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.6 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
coder_so.coefs(A,coder_so.z,2)
# Out:
# [-1, 0, 0]

# %%
A=coder_so.SymT(N=1)
A.print_nice()
# Out:
# <style>.container{width:auto!important;}
#  .output_area img{width:auto!important;}
#  .rendered_html img{width:auto!important;}</style><nobr /><img src="data:image/png;base64,..." style="max-width:none;"/><nobr />
